# %% [markdown]
# <a href="https://colab.research.google.com/github/FabioRovai/DEEPWALL-E/blob/main/Deep_Daze.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deep-daze --upgrade
# Out:
# ...
#      |████████████████████████████████| 1.4MB 8.7MB/s
# ...
#      |████████████████████████████████| 92kB 9.2MB/s
# ...
#      |████████████████████████████████| 81kB 11.6MB/s
# ...
#      |████████████████████████████████| 3.3MB 48.1MB/s
# ...
#      |████████████████████████████████| 71kB 11.0MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115943 sha256=b891c3570ff2108c57e9da4729c2c2b08757be299ad00a350b62205a391d474f
#   Stored in directory: /root/.cache/pip/wheels/af/19/30/1ea0cad502dcb4e66ed5a690279628c827aea38bbbab75d5ed
# ...
#   Created wheel for ftfy: filename=ftfy-6.0.3-cp37-none-any.whl size=41935 sha256=9ba05732b704287ee9ae10a7820743ba8b00c7e77c098e15026e810c8eaee755
#   Stored in directory: /root/.cache/pip/wheels/99/2c/e6/109c8a28fef7a443f67ba58df21fe1d0067ac3322e75e6b0b7
# Successfully built fire ftfy
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: imageio 2.4.1
# ...

# %%
from tqdm.notebook import trange
from IPython.display import Image, display

from deep_daze import Imagine

TEXT = 'a face in the sky with tattoo' #@param {type:"string"}
NUM_LAYERS = 32 #@param {type:"number"}
SAVE_EVERY =  100#@param {type:"number"}
IMAGE_WIDTH = 128*3 #@param {type:"number"}
SAVE_PROGRESS = True #@param {type:"boolean"}
LEARNING_RATE = 1e-5 #@param {type:"number"}
ITERATIONS = 1050 #@param {type:"number"}

model = Imagine(
    text = TEXT,
    num_layers = NUM_LAYERS,
    save_every = SAVE_EVERY,
    image_width = IMAGE_WIDTH,
    lr = LEARNING_RATE,
    iterations = ITERATIONS,
    save_progress = SAVE_PROGRESS
)

for epoch in trange(20, desc = 'epochs'):
    for i in trange(ITERATIONS, desc = 'iteration'):
        model.train_step(epoch, i)

        if i % model.save_every != 0:
            continue

        filename = TEXT.replace(' ', '_')
        image = Image(f'./{filename}.jpg')
        display(image)
# Out:
# ...
# Setting jit to False because torch version is not 1.7.1.
# ...
# image updated at "./a_face_in_the_sky_with_tattoo.jpg"
# image updated at "./a_face_in_the_sky_with_tattoo.000001.jpg"
# image updated at "./a_face_in_the_sky_with_tattoo.000002.jpg"
# image updated at "./a_face_in_the_sky_with_tattoo.000003.jpg"
# image updated at "./a_face_in_the_sky_with_tattoo.000004.jpg"
# image updated at "./a_face_in_the_sky_with_tattoo.000005.jpg"
# image updated at "./a_face_in_the_sky_with_tattoo.000006.jpg"
# image updated at "./a_face_in_the_sky_with_tattoo.000007.jpg"
# image updated at "./a_face_in_the_sky_with_tattoo.000008.jpg"
